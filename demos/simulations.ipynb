# %% [markdown]
# # Tutorial for Simulations

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns

# %%
sns.color_palette('Set1')
sns.set(color_codes=True, style='white', context='talk', font_scale=1)

import sys
module_path = '/Users/spanda/Essential/580.638 - NeuroData II/mgcpy'
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# First, import the simultions utilizing the import statement below:

# %%
from mgcpy.benchmarks import simulations as sims

# %% [markdown]
# Simultions are randomly generated with an $x$ which is $(n\cdot d)$ and $y$ which is $(n\cdot 1)$ that have 2 required parameters: `num_samp` or the number of samples, and `num_dim` or the number of dimensions. Optional parameters can be set based on the documentation. Visualizations of the 4 simulations imported above are shown below with and without the noise. Each simulation is also shown in 2D.
#
# For all the below simulations, $(X, Y) \overset{i.i.d}{\sim} F_{XY}=F_{Y|X}F_{X}$ where $X$ and $Y$ are independently identically distributed.

# %% [markdown]
# ## Linear Simulation

# %% [markdown]
# Linear $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}$:
#
# $$X \sim \mathcal{U}(-1,1)^{p}$$
#
# $$Y=w^{T}X+\kappa \epsilon$$

# %%
x_normal, y_normal = sims.linear_sim(100, 1)
x_no_noise, y_no_noise = sims.linear_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Linear', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Exponential Simulation

# %% [markdown]
# Exponential $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}$:
#
# $$X \sim \mathcal{U}(0,3)^{p}$$
#
# $$Y=\exp(w^{T}X)+10\kappa \epsilon$$

# %%
x_normal, y_normal = sims.exp_sim(100, 1)
x_no_noise, y_no_noise = sims.exp_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Exponential Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Cubic Simulation

# %% [markdown]
# Cubic $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}$:
#
# $$X \sim \mathcal{U}(-1,1)^{p}$$
#
# $$Y=128\left(w^{T}X-\frac{1}{3}\right)^{3}+48\left(w^{T}X-\frac{1}{3}\right)^{2}-12\left(w^{T}X-\frac{1}{3}\right)+80\kappa \epsilon$$

# %%
x_normal, y_normal = sims.cub_sim(100, 1)
x_no_noise, y_no_noise = sims.cub_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Cubic Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Joint-Normal Simulation

# %% [markdown]
# Joint normal $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}^{p}$: Let $\rho=1/2p$, $I_{p}$ be the identity matrix of size $p\times p$, $J_{p}$ be the matrix of ones of size $p\times p$, and $\Sigma =\begin{bmatrix}
#     I_{p} & \rho J_{p} \\
#     \rho J_{p} & (1+0.5\kappa)I_{p}\\
# \end{bmatrix}$. Then
#
# $$(X,Y) \sim \mathcal{N}(0,\Sigma)$$

# %%
x_normal, y_normal = sims.joint_sim(100, 1)
x_no_noise, y_no_noise = sims.joint_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Joint-Normal Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Step Function Simulation

# %% [markdown]
# Step Function $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}$:
#
# $$X \sim \mathcal{U}(-1,1)^{p}$$
#
# $$Y=\textbf{I}(w^{T}X>0)+\epsilon$$
#
# where $\textbf{I}$ is the indicator function, that is $\textbf{I}(z)$ is unity whenever $z$ is true, and $0$ otherwise.

# %%
x_normal, y_normal = sims.step_sim(100, 1)
x_no_noise, y_no_noise = sims.step_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Step Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Quadratic Simulation

# %% [markdown]
# Quadratic $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}$:
#
# $$X \sim \mathcal{U}(-1,1)^{p}$$
#
# $$Y=(w^{T}X)^{2}+0.5\kappa \epsilon$$

# %%
x_normal, y_normal = sims.quad_sim(100, 1)
x_no_noise, y_no_noise = sims.quad_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Quadratic Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## W-Shaped Simulation

# %% [markdown]
# W-Shape $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}$: $U \sim \mathcal{U}(-1,1)^{p}$,
#
# $$X \sim \mathcal{U}(-1,1)^{p}$$
#
# $$Y=4\left[\left((w^{T}X)^{2}-\frac{1}{2}\right)^{2}+w^{T}U/500\right]+0.5\kappa\epsilon$$

# %%
x_normal, y_normal = sims.w_sim(100, 1)
x_no_noise, y_no_noise = sims.w_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('W-Shaped Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Spiral Simulation

# %% [markdown]
# Spiral $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}$: $U \sim \mathcal{U}(0,5)$, $\epsilon\sim\mathcal{N}(0,1)$,
# <br></br>
# <br></br>
# <center>$X_{|d|}=U\sin(\pi U)\cos^{d}(\pi U)$ for $d=1,...,p-1$</center>
#
# $$X_{|p|}=U\cos^{p}(\pi U)$$
#
# $$Y=U\sin(\pi U)+0.4p\epsilon$$

# %%
x_normal, y_normal = sims.spiral_sim(100, 1)
x_no_noise, y_no_noise = sims.spiral_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Spiral Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Uncorrelated Bernoulli Simulation

# %% [markdown]
# Uncorrelated Bernoulli $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}$: $U \sim \mathcal{B}(0.5)$, $\epsilon_{1}\sim \mathcal{N}(0,I_{p})$, $\epsilon_{2}\sim \mathcal{N}(0,1)$,
#
# $$X \sim \mathcal{B}(0.5)^{p}+0.5\epsilon_{1}$$
#
# $$Y=(2U-1)w^{T}X+0.5\epsilon_{2}$$

# %%
x_normal, y_normal = sims.ubern_sim(100, 1)
x_no_noise, y_no_noise = sims.ubern_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Uncorrelated Bernoulli Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Logarithmic Simulation

# %% [markdown]
# Logarithmic $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}^{p}$: $\epsilon\sim\mathcal{N}(0,I_{p})$,
#
# $$X \sim \mathcal{N}(0,I_{p})$$
# <br></br>
# <center>$Y_{|d|}=2\log _{2}{(|X_{|d|}|)}+3\kappa\epsilon_{|d|}$ for $d=1,...,p$</center>

# %%
x_normal, y_normal = sims.log_sim(100, 1)
x_no_noise, y_no_noise = sims.log_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Logarithmic Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Fourth-Root Simulation

# %% [markdown]
# Fourth-Root $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}$:
#
# $$X \sim \mathcal{U}(-1,1)^{p}$$
#
# $$Y=|w^{T}X|^{\frac{1}{4}}+\frac{\kappa}{4}\epsilon$$

# %%
x_normal, y_normal = sims.root_sim(100, 1)
x_no_noise, y_no_noise = sims.root_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Fourth-Root Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Sinusoidal (4$\pi$) Simulation

# %% [markdown]
# Sine Period 4$\pi$ $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}^{p}$: $U\sim\mathcal{U}(-1,1)$, $V\sim\mathcal{N}(0,1)^{p}$, $\theta=4\pi$,
# <br></br>
# <br></br>
# <center>$X_{|d|}=U+0.02pV_{|d|}$ for $d=1,...,p$</center>
#
# $$Y=\sin(\theta X)+\kappa \epsilon$$

# %%
x_normal, y_normal = sims.sin_sim(100, 1)
x_no_noise, y_no_noise = sims.sin_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Sinusoidal (4$\pi$) Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Sinusoidal (16$\pi$) Simulation

# %% [markdown]
# Sine Period 16$\pi$ $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}^{p}$: Same as above except $\theta=16\pi$ and the noise on $Y$ is changed to $0.5\kappa \epsilon$.

# %%
x_normal, y_normal = sims.sin_sim(100, 1, period=16*np.pi)
x_no_noise, y_no_noise = sims.sin_sim(1000, 1, noise=0, period=16*np.pi)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Sinusoidal (16$\pi$) Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Square Simulation

# %% [markdown]
# Square $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}^{p}$: $U\sim\mathcal{U}(-1,1)$, $V\sim\mathcal{U}(-1,1)$, $\epsilon\sim\mathcal{N}(0,1)^{p}$, $\theta=-\frac{\pi}{8}$,
#
# $$X_{|d|}=U\cos(\theta)+V\sin(\theta)+0.05p\epsilon_{|d|}$$
#
# $$Y_{|d|}=-U\sin(\theta)+V\cos(\theta)$$

# %%
x_normal, y_normal = sims.square_sim(100, 1)
x_no_noise, y_no_noise = sims.square_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Square Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Diamond Simulation

# %% [markdown]
# Diamond $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}^{p}$: Same as above except $\theta=-\frac{\pi}{4}$.

# %%
x_normal, y_normal = sims.square_sim(100, 1, period=-np.pi/4)
x_no_noise, y_no_noise = sims.square_sim(1000, 1, noise=0, period=-np.pi/4)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Diamond Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Two Parabolas Simulation

# %% [markdown]
# Two Parabolas $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}$: $\epsilon\sim\mathcal{U}(0,1)$, $U\sim\mathcal{B}(0.5)$,
#
# $$X \sim \mathcal{U}(-1,1)^{p}$$
#
# $$Y=\left((w^{T}X)^{2}+2\kappa\epsilon\right)\cdot\left(U-\frac{1}{2}\right)$$

# %%
x_normal, y_normal = sims.two_parab_sim(100, 1)
x_no_noise, y_no_noise = sims.two_parab_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Two Parabolas Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Circle Simulation

# %% [markdown]
# Circle $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}$: $U\sim\mathcal{U}(-1,1)^{p}$, $\epsilon\sim\mathcal{N}(0,I_{p})$, $r=1$,
# <br></br>
# <br></br>
# <center>$X_{|d|}=r\left(\sin(\pi U_{|d+1|})\prod\limits_{j=1}^d \cos(\pi U_{|j|})+0.4\epsilon_{|d|}\right)$ for $d=1,...,p-1$</center>
#
# $$X_{|d|}=r\left(\prod\limits_{j=1}^p \cos(\pi U_{|j|})+0.4\epsilon_{|p|}\right)$$
#
# $$Y_{|d|}=\sin(\pi U_{|1|})$$

# %%
x_normal, y_normal = sims.circle_sim(100, 1)
x_no_noise, y_no_noise = sims.circle_sim(1000, 1, noise=0)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Circle Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Ellipse Simulation

# %% [markdown]
# Ellipse $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}^{p}$: Same as above except $r=5$.

# %%
x_normal, y_normal = sims.circle_sim(100, 1, radius=5)
x_no_noise, y_no_noise = sims.circle_sim(1000, 1, noise=0, radius=5)

# %%
# Note change in X axis compared to circle simulation
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal (with noise)', alpha=0.5)
ax1.scatter(x_no_noise, y_no_noise, c='r', label='No noise')
ax1.set_title('Ellipse Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Multiplicative Noise Simulation

# %% [markdown]
# Multiplicative Noise $(x,y) \in \mathbb{R}^{p} \times \mathbb{R}^{p}$: $u\sim\mathcal{N}(0,I_{p})$,
#
# $$x \sim \mathcal{N}(0,I_{p})$$
# <br></br>
# <center>$y_{|d|}=u_{|d|}x_{|d|}$ for $d=1,...,p$</center>

# %%
# Note that this simulation has no noise parameter
x_normal, y_normal = sims.multi_noise_sim(1000, 1)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal')
ax1.set_title('Multiplicative Noise Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()

# %% [markdown]
# ## Multimodal Independence Simulation

# %% [markdown]
# Multimodal Independence $(X,Y) \in \mathbb{R}^{p} \times \mathbb{R}$: $U\sim\mathcal{N}(0,I_{p})$, $V\sim\mathcal{N}(0,I_{p})$, $U'\sim\mathcal{B}(0.5)^{p}$, $V'\sim\mathcal{B}(0.5)^{p}$
#
# $$X=U/3+2U'-1$$
#
# $$Y=V/3+2V'-1$$

# %%
# Note that this simulation has no noise parameter
x_normal, y_normal = sims.multi_indep_sim(1000, 1)

# %%
fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(x_normal, y_normal, c='b', label='Normal')
ax1.set_title('Multimodal Independence Simulation', fontweight='bold')
ax1.set_xlabel('X Vector')
ax1.set_ylabel('Y Vector')
plt.legend(bbox_to_anchor=(1.3, 0.9), bbox_transform=plt.gcf().transFigure)
plt.show()
